# %%
dbutils.widgets.text("v_file_date", "2021-03-21")
v_file_date = dbutils.widgets.get("v_file_date")

# %%
# %run "../includes/common_code"

# %%
display(dbutils.fs.ls(processed_container_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Get the required dataframes from processed to build the races result into presentation folder
# 1. races dataframe
# 2. pitstops dataframe
# 3. circuit dataframe
# 4. results dataframe
# 5. drivers dataframe
# 6. constructors dataframe

# %%
circuits_df = spark.read.format("delta").load(f"{processed_container_path}/circuits")

# %%
display(circuits_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
drivers_df = spark.read.format("delta").load(f"{processed_container_path}/drivers").withColumnRenamed("number", "driver_number")

# %%
display(drivers_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
drivers_df.filter(drivers_df.driver_name == "Max Verstappen").show()
# Out:
# +----+----------+---------+--------------+--------------+-----------+-------------+----------+--------------------+
# |code|       dob|driver_id|    driver_ref|   driver_name|nationality|driver_number| file_date|         ingest_date|
# +----+----------+---------+--------------+--------------+-----------+-------------+----------+--------------------+
# | VER|1997-09-30|      830|max_verstappen|Max Verstappen|      Dutch|           33|2021-03-21|2025-04-18 12:36:...|
# +----+----------+---------+--------------+--------------+-----------+-------------+----------+--------------------+

# %%
constructors_df = spark.read.format("delta").load(f"{processed_container_path}/constructors").withColumnRenamed("name", "team_name")

# %%
display(constructors_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
constructors_df.filter(constructors_df.team_name == "Red Bull").show()
# Out:
# +--------------+---------------+---------+-----------+----------+--------------------+
# |constructor_id|constructor_ref|team_name|nationality| file_date|         ingest_date|
# +--------------+---------------+---------+-----------+----------+--------------------+
# |             9|       red_bull| Red Bull|   Austrian|2021-03-21|2025-04-18 12:35:...|
# +--------------+---------------+---------+-----------+----------+--------------------+

# %%
races_df = spark.read.format("delta").load(f"{processed_container_path}/races").withColumnRenamed("name", "race_name") \
                                                                  .withColumnRenamed("time", "race_time") \
                                                                  .withColumnRenamed("date", "race_date")

# %%
display(races_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
pit_stops_df = spark.read.format("delta").load(f"{processed_container_path}/pit_stops")

# %%
display(pit_stops_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
results_df = spark.read.format("delta").load(f"{processed_container_path}/results").filter(f"file_date == '{v_file_date}'")

# %%
display(results_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### The results should look similar to what is shown in [BBC results page](https://www.bbc.com/sport/formula1/2021/abu-dhabi-grand-prix/results)

# %% [markdown]
# What columns we need from different tables?
# 1. race_year, race_name, race_date from races_df
# 2. circuit_name from circuits_df
# 3. driver_name, driver_nationality, driver_number from drivers_df
# 4. team_name from constructors_df
# 5. grid, fastest_lap_time, time, points from results_df
#
# Order of the columns displayed should be **race_year, race_name, circuit_name, race_date, driver_nationality, driver_name, team_name, driver_number, grid, fastest_lap_time, time, points**

# %% [markdown]
# How to combine different tables using joins?
# 1. We need circuit_name from circuits_df but results_df don't has circuit_id. So to get circuit_id we combine races_df with circuits_df
# 2. Combine results_df with the above result along with drivers_df and constructors_df

# %%
# Join the races and circuits tables using inner join
races_circuits_df = races_df.join(circuits_df, races_df.circuit_id == circuits_df.circuit_id, "inner") \
                                      .select(races_df.race_id, races_df.race_year, races_df.race_name, circuits_df.circuit_name, races_df.race_date)

# %%
# join results dataframe with the resultant above
race_results_df = results_df.join(races_circuits_df, results_df.race_id == races_circuits_df.race_id, "inner") \
                            .join(drivers_df, results_df.driver_id == drivers_df.driver_id, "inner") \
                            .join(constructors_df, results_df.constructor_id == constructors_df.constructor_id, "inner") \
                            .select(results_df.race_id, races_circuits_df.race_year, races_circuits_df.race_name, 
                                    races_circuits_df.circuit_name, races_circuits_df.race_date, drivers_df.nationality, drivers_df.driver_name, constructors_df.team_name, drivers_df.driver_number, results_df.grid, results_df.fastest_lap_time, results_df.time, results_df.points, results_df.position, results_df.file_date)

# %%
display(race_results_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import desc

# %%
display(race_results_df.filter((race_results_df.race_date == f"{v_file_date}")).orderBy(desc(race_results_df.points)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Yay! The result now matches with the one that is present as part of [BBC](https://www.bbc.com/sport/formula1/2020/abu-dhabi-grand-prix/results) results page. Now write the race_results_df into presentation layer

# %%
merge_condition = "target.driver_name = source.driver_name AND target.race_id = source.race_id"
mergeTable(race_results_df, 'f1_presentation', 'race_results', merge_condition, 'race_id')

# %%
# overwrite_partition(race_results_df, "f1_presentation", "race_results", "race_id")

# %%
dbutils.notebook.exit("Success")
